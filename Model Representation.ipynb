# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
m
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2
# 2

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker ='*', c = 'r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
# creating model function f=wx+b
def compute_model(x,w,b):
    m=x.shape[0]
    f= np.zeros(m)
    for i in range(m):
        f[i] = w*x[i] +b
        
    return f

# %%
f_es = compute_model(x_train , 250,15)

plt.plot(x_train , f_es, c='g', label ='Our prediction')

# plt.plot(x_train,y_train, c='r' ,label ='Actual plot')

# plt.scatter(x_train,f_es ,marker ='*')
plt.scatter(x_train,y_train ,marker ='*',c='r',label ='Actual values')

plt.title("Housing Price")
plt.xlabel("Size in Square feet")
plt.ylabel("Price in 1000's doller")
#  to use label as hue in seaborn use legend()
plt.legend()
plt.show()

# %%
x = int(input("Enter a value: "))
w= 250
b= 15
cost_x = w*x +b

print(f"The cost of {x} = {cost_x}k")
# Out:
# Enter a value: 2
# The cost of 2 = 515k
